# %%
def mul(a,b):
    return(a*b)
mul(10,39)
# Out:
# 390

# %%
mul=lambda a,b:a*b
mul(10,20)
# Out:
# 200

# %%
mul=lambda a,b,c:a*b*c
mul(10,20,30)
# Out:
# 6000

# %%
mul=lambda a,b,c=200:a*b*c
mul(10,20)
# Out:
# 40000

# %%
l=['hyg','fgff']
ans=[i.capitalize() for i in l]
ans
# Out:
# ['Hyg', 'Fgff']

# %%
l=['hyg','fgff']
ans=[i.upper() for i in l]
ans
# Out:
# ['HYG', 'FGFF']

# %%
summ=0
l=['hyg','fgff','fdds','rfds']
for i in l:
    summ=summ+l.index(i)
    print(summ)
# Out:
# 0
# 1
# 3
# 6

# %%
ans=[l.index(i) for i in l]
sum(ans)
# Out:
# 6

# %%
l=['hyg','fg#f','f#ds','rfds']
ans=[i for i in l if '#' in i]
ans
# Out:
# ['fg#f', 'f#ds']
