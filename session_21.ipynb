# %%
dict1={'ramesh':20,'suresh':30,'sathish':40}
dict2={20:'ramesh'}
dict2
print(dict1)
# Out:
# {'ramesh': 20, 'suresh': 30, 'sathish': 40}

# %%
d1={20:'yyyy',30:'suresh',30:'sathish'}
d1
# Out:
# {20: 'yyyy', 30: 'sathish'}

# %%
dict1={'ramesh':20,'ramesh':30}
min(dict1)
# Out:
# 'ramesh'

# %%
dict1={'ramesh':20,'saresh':50,'sashish':100}
max(dict1)
# Out:
# 'sashish'

# %%
dict1={'ramesh':20,'suresh':30,'sathish':40}
min(dict1)
# Out:
# 'ramesh'

# %%
d1={100:'yyyy',30:'suresh',40:'sathish'}
max(d1)
# Out:
# 100

# %%
d1={20:'yyyy',30:'suresh',40:'sathish'}
min(d1)
# Out:
# 20

# %%
dict1={'ramesh':'20','suresh':'30','sathish':'40'}
dict1
# Out:
# {'ramesh': '20', 'suresh': '30', 'sathish': '40'}

# %%
dict1={'ramesh':'20','suresh':'30','sathish':'40'}
min(dict1)
# Out:
# 'ramesh'

# %%
dict1={'ramesh':'20','suresh':'30','sathish':'40'}
max(dict1), len(dict1), sorted(dict1),reversed(dict1)#,sum(dict1)
# Out:
# ('suresh',
#  3,
#  ['ramesh', 'sathish', 'suresh'],
#  <dict_reversekeyiterator at 0x15513f519e0>)

# %%
str='Hi how are you'
str1=[]
for i in str.split():
    str1.append(i.title())
str1
# Out:
# ['Hi', 'How', 'Are', 'You']

# %%
dict1={2:'20',33:'30','sathish':'40'}
dict1
# Out:
# {2: '20', 33: '30', 'sathish': '40'}

# %%
dict1={sathish:'40'}
dict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 dict1={sathish:'40'}
#       2 dict1
#
# NameError: name 'sathish' is not defined

# %%
dict1={'mbmb':'sathish'}
dict1
# Out:
# {'mbmb': 'sathish'}

# %%
dict1={'sathish':20,'sathish':20}
dict1
# Out:
# {'sathish': 20}

# %%
d={[10,22,33]:'sd'}
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 d={[10,22,33]:'sd'}
#       2 d
#
# TypeError: unhashable type: 'list'

# %%
d={'sd':[10,22,33]}
d
# Out:
# {'sd': [10, 22, 33]}

# %%
s={{'ffsef':33}:'sfsdf'}
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 s={{'ffsef':33}:'sfsdf'}
#       2 s
#
# TypeError: unhashable type: 'dict'

# %%
s={'sfsdf':{'ffsef':33}}
s
# Out:
# {'sfsdf': {'ffsef': 33}}

# %%
s={{'sfsdf':432}:{'ffsef':33}}
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 s={{'sfsdf':432}:{'ffsef':33}}
#       2 s
#
# TypeError: unhashable type: 'dict'

# %%
s={('sfsdf'):{'ffsef':33}}
s
# Out:
# {'sfsdf': {'ffsef': 33}}

# %%
d1={20:'yyyy',30:'suresh',40:'sathish'}
max(d1)
# Out:
# 40

# %%
d1={20:'yyyy',30:'suresh',40:'sathish'}
sum(d1)
# Out:
# 90

# %%
dict1={'ramesh':20,'suresh':30,'sathish':40}
len(dict1)
# Out:
# 3

# %%
dict1={'ramesh':20,'suresh':30,'sathish':40}
sorted(dict1)
# Out:
# ['ramesh', 'sathish', 'suresh']

# %%
dict1={'ramesh':20,'suresh':30,'sathish':'efe'}
sorted(dict1)
# Out:
# ['ramesh', 'sathish', 'suresh']

# %%
d1={20:'yyyy',30:'suresh',40:'sathish'}
sorted(d1)
# Out:
# [20, 30, 40]

# %%
d1={20:'yyyy',30:'suresh',40:'sathish'}
sorted(d1)
# Out:
# [20, 30, 40]

# %%
d1={20:'yyyy',30:'suresh',40:'sathish'}
list(reversed(d1))
# Out:
# [40, 30, 20]

# %%
dict1={'ramesh':20,'suresh':30,323:'efe'}
list(reversed(dict1))
# Out:
# [323, 'suresh', 'ramesh']

# %%
dict1={'ramesh':20,'suresh':30,'sathish':'efe'}
d1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[195], line 2
#       1 dict1={'ramesh':20,'suresh':30,'sathish':'efe'}
# ----> 2 d1[0]
#
# KeyError: 0

# %%
dict1={'ramesh':20,'suresh':30,'sathish':'efe'}
dict1['ramesh'],dict1['suresh'],dict1['sathish']
# Out:
# (20, 30, 'efe')

# %%
for i in dict1:
    print(i,dict1[i])
# Out:
# ramesh 20
# suresh 30
# sathish efe

# %%
d1={'fruits':['apple','banana','cherry']}
d1['fruits'][0:2]
# Out:
# ['apple', 'banana']

# %%
d1={'fruits':{'apple':['banana','cherry']}}
d1['fruits']['apple'][1]
# Out:
# 'cherry'

# %%
d1={'fruits':[{'apple':[100,200,300]}]}
d1['fruits'][0]['apple'][2]
# Out:
# 300

# %%
d1={'fruits':['apple'],'cost':[{'1kg':[300,500],'2kg':['none']}]}
d1
# Out:
# {'fruits': ['apple'], 'cost': [{'1kg': [300, 500], '2kg': ['none']}]}

# %%
d1={'fruits':['apple'],'cost':[{'1kg':[300,500],'2kg':['none']}]}
d1['cost'][0]['2kg'][0]
# Out:
# 'none'

# %%
d1={'fruits':{'apple':{'cost':{'xdxsd':{'dawscxsd':{'wdwd'}}}}}}
d1['fruits']['apple']['cost']['xdxsd']['dawscxsd']
# Out:
#   Cell In[344], line 2
#     d1['fruits']['apple']['cost']['xdxsd']['dawscxsd'][]
#                                                        ^
# SyntaxError: invalid syntax

# %%
d1={'fruits':['apple','banana','cherry']}
d1
# Out:
# {'fruits': ['apple', 'banana', 'cherry']}
