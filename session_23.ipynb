# %%
file name='Tmbpx-short.txt'
file=open(file_name)
data=file.read()

for i in data:
    print(i)
# Out:
#   Cell In[3], line 1
#     file name='mbpx-short.txt'
#          ^
# SyntaxError: invalid syntax
