# %%
n=['gdf','dsgf','egdfvd']
l=[2,3,4]
dict1={}
for i,j in zip(n,l):
    print(i,j)
# Out:
# gdf 2
# dsgf 3
# egdfvd 4

# %%
n=['gdf','dsgf','egdfvd']
l=[2,3,4]
dict1={}
dict1['gdf']=2
dict1['dsgf']=3
dict1['egdfvd']=4
dict1[i]=j

# %%
n={'naveen':10,'suresh':20,'naresh':30}
n2=[]
n3=[]
for i in n:
    print(i)
    print(d[key])
    values.append(d[key])
# Out:
# naveen
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 6
#       4 for i in n:
#       5     print(i)
# ----> 6     print(d[key])
#       7     values.append(d[key])
#
# NameError: name 'd' is not defined
